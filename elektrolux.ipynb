# %%
import json

import numpy as np
import pandas as pd
import requests

# %%
#Download data from elektrolux
url = "https://api.eluxmkt.com/external/commerce/ccv2/occ/POL-ELX/products/compare?query=:relevance:category:kitchen%2fcooking%2fovens%2fsteam-oven&currentPage=0&pageSize=100"

payload = {}
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:132.0) Gecko/20100101 Firefox/132.0',
    'TE': 'trailers',
    'Referer': 'https://www.electrolux.pl/',
    'Origin': 'https://www.electrolux.pl/',
}

response = requests.request("GET", url, headers=headers, data=payload)

file = open("response_elektrolux.json", "w")
file.write(response.text)
file.close()

# %%
file = open('response_elektrolux.json', 'r')
data = json.load(file)
file.close()

# %%
index_main = []
index_sub = []

for item in data['products']:
    for spec in item['specifications']:
        if spec['name'] == 'CookingFunctions':
            for item in spec['value'].split('|'):
                val = 'Tryb_' + item
                if val not in index_sub:
                    index_main.append('Performance')
                    index_sub.append(val)

for item in data['products']:
    for spec in item['specifications']:
        if spec['name'] != 'CookingFunctions':
            if spec['translatedName'] not in index_sub:
                index_main.append(spec['groupName'])
                index_sub.append(spec['translatedName'])

for item in data['products']:
    for spec in item['extendedSpecifications']:
        if spec['translatedName'] not in index_sub:
                index_main.append(spec['groupName'])
                index_sub.append(spec['translatedName'])

index_main.append('Other')
index_sub.append('Cena')
index_main.append('Other')
index_sub.append('Nazwa')
arrays = [
    np.array(index_main),
    np.array(index_sub)
]
arrays
# Out:
# [array(['Performance', 'Performance', 'Performance', 'Performance',
#         'Performance', 'Performance', 'Performance', 'Performance',
#         'Performance', 'Performance', 'Performance', 'Performance',
#         'Performance', 'Performance', 'Performance', 'Performance',
#         'Performance', 'Performance', 'Performance', 'Performance',
#         'Performance', 'Performance', 'Performance', 'Performance',
#         'Performance', 'Performance', 'Performance', 'Performance',
#         'Performance', 'Performance', 'Performance', 'Performance',
#         'Performance', 'Other', 'Energy', 'Installation', 'Performance',
#         'Installation', 'Other', 'Performance', 'Performance',
#         'Performance', 'Installation', 'Performance', 'Performance',
#         'Performance', 'Performance', 'Performance', 'Other', 'Energy',
#         'Energy', 'Energy', 'Energy', 'Energy', 'Other', 'Performance',
#         'Installation', 'Installation', 'Other', 'Other', 'Other',
#         'Installation', 'Installation', 'Performance', 'Other', 'Other',
#         'Performance', 'Other', 'Other', 'Installation', 'Installation',
#         'Installation', 'Other', 'Other', 'Performance', 'Performance',
#         'Performance', 'Other', 'Other', 'Installation', 'Installation',
#         'Installation', 'Installation', 'Installation', 'Installation',
#         'Installation', 'Installation', 'Other', 'Other', 'Other', 'Other',
#         'Other', 'Other', 'Other'], dtype='<U12'),
#  array(['Tryb_Au Gratin', 'Tryb_grzanie dolne', 'Tryb_pieczenie chleba',
#         'Tryb_konwencjonalne/tradycyjne pieczenie', 'Tryb_rozmrażanie',
#         'Tryb_utrzymywanie temperatury', 'Tryb_powolne gotowanie',
#         'Tryb_regeneracja parowa ', 'Tryb_Steamify', 'Tryb_termoobieg',
#         'Tryb_grillowanie turbo', 'Tryb_wyrastanie ciasta',
#         'Tryb_suszenie', 'Tryb_zamrożone potrawy', 'Tryb_para 100%',
#         'Tryb_grill', 'Tryb_duża wilgotność', 'Tryb_mała wilgotność',
#         'Tryb_utrzymywanie ciepła', 'Tryb_nawilżanie', 'Tryb_pizza',
#         'Tryb_ogrzewanie talerzy', 'Tryb_pieczenie z parą',
#         'Tryb_szybkie grillowanie', 'Tryb_delikatne',
#         'Tryb_termoobieg/ STEAM BAKE', 'Tryb_średnia wilgotność',
#         'Tryb_SousVide', 'Tryb_funkcja Yoghurt',
#         'Tryb_ogrzewanie górne/dolne', 'Tryb_Dehydrating',
#         'Tryb_termoobieg z parą', 'Tryb_szybkie nagrzewanie', 'Kolor',
#         'Klasa efektywności energetycznej',
#         'Wymiary w zabudowie (W x S x G) [mm]', 'Funkcja Connectivity',
#         'Całkowity pobór mocy [W]', 'Poziom pary', 'Wyświetlacz',
#         'Pojemność użytkowa [l]', 'Sposób czyszczenia',
#         'Wymiary WxSzxG [mm]', 'Interfejs', 'Moc grilla [W]',
#         'Maks. moc piekarnika [W]', 'Zakres temperatur',
#         'Powierzchnia największej płyty grzewczej - górny piekarnik [cm2] ',
#         'Oświetlenie', 'Energy efficiency index EEI',
#         'Zużycie energii przy standardowym obciążeniu [kW]',
#         'Zużycie energii, wentylator [kWh/cykl]', 'Moc oświetlenia [W]',
#         'Typ piekarnika', 'Typ\n', 'Poziom hałasu [dB] - górny piekarnik',
#         'Waga brutto [kg]', 'Waga netto [kg]',
#         'Brytfanny dołączone do piekarnika', 'Rodzaj rusztu', 'Prowadnice',
#         'Długość przewodu [m]', 'Rodzaj wtyczki',
#         'Maks. temperatura powierzchni drzwi [°C] (zgodnie z normą EN30 lub 60335-1)',
#         'Wyposażenie', 'Komora', 'Nø of cavities', 'Kod produktu (PNC)',
#         'Kod EAN', 'Napięcie [V]', 'Wymagany bezpiecznik [A]',
#         'Instalacja', 'Funkcja CookView', 'Rodzaj wyświetlacza',
#         'Tryby gotowania', 'Moc grzałki dolnej [W]',
#         'Moc grzałki grilla [W]', 'Moc grzałki termoobiegu [W]',
#         'Delikatne domykanie', 'Wysokość [mm]', 'Szerokość [mm]',
#         'Głębokość [mm]', 'Wysokość niszy [mm]', 'Szerokość niszy [mm]',
#         'Wysokość opakowania [mm]', 'Szerokość opakowania [mm]',
#         'Głębokość opakowania [mm]', 'EcoLine', 'Master model', 'Linia',
#         'Seria', 'Kod partnera', 'Cena', 'Nazwa'], dtype='<U75')]

# %%
model_products = []
for item in data['products']:
    model_products.append(item['modelId'])
model_products = list(set(model_products))
model_products
# Out:
# ['EOD6C77Z',
#  'EOD6P77Z',
#  'EOD6C77V',
#  'KOCDH76X',
#  'KOBBS39X',
#  'EOD5C70BX',
#  'COB8S39WZ',
#  'COC8H31Z',
#  'EOB7S31Z',
#  'EOC8P39WX',
#  'KVBAS21WX',
#  'EOA9S31CX',
#  'EOD5C50Z',
#  'KOAAS31CX',
#  'KOBCS31Z',
#  'EOC6P77H',
#  'EOC5E70X',
#  'EOD6C77WZ',
#  'EOD3H50BK',
#  'Y6POD57X',
#  'EOD6C77X',
#  'EOB9S31WX',
#  'KOAAS31WX',
#  'LOB8S39Z',
#  'KOCBP39WX',
#  'EOD3C50TX',
#  'KODDP77X',
#  'Y8SOB39X',
#  'KOBBS39WX',
#  'EOD5H70BX',
#  'EOD3C70TK',
#  'KODEH70X',
#  'EOC8P39H',
#  'EOD5C71X',
#  'EOC8H31Z',
#  'EOC6H71Z',
#  'EOD5H70BZ',
#  'EOC6H76Z',
#  'KODEC70BZ',
#  'LOD6C77Z',
#  'EOB8S39WX',
#  'EOB8S39WZ',
#  'EOD6C77WX',
#  'LOC8H31X',
#  'KODEC75X',
#  'EOC8H39WX',
#  'KOCDH76Z',
#  'COB8S39Z',
#  'EOC6H76X',
#  'EOC6P77V',
#  'EOC8H39X',
#  'KOD3C70X',
#  'EOB7S31X',
#  'LOB8S39WZ',
#  'EOD6P77X',
#  'EOD6P77WX',
#  'KOCAP31WT',
#  'LOD6C77WZ',
#  'KOABS39WX',
#  'EOD4P57H',
#  'KOCBP39H',
#  'EOD6F77WV',
#  'EOC9P31WX',
#  'EOD6C77WV',
#  'EOD5C70X',
#  'EOA9S31WZ',
#  'EOB7S31V',
#  'KOD5C70BX',
#  'Y6POC77X',
#  'EOD5C70BZ',
#  'KODDP77H',
#  'KODEC75X2',
#  'EOABS39Z',
#  'EOD6P77WZ',
#  'KOABS39X',
#  'EOC8P39WZ',
#  'KOBBS39H',
#  'LOC6H76Z',
#  'EOD5F71X',
#  'EOB8S39H',
#  'EOD3F50TX',
#  'EOD6F77WZ',
#  'EOD6C77H',
#  'KODEC75Z2',
#  'KOBCS31X',
#  'KODDP77WX',
#  'EOD3H40BX',
#  'KOAAS31WT',
#  'EOC6H71X',
#  'EOD5C71Z',
#  'EOABS39WZ',
#  'EOD3H70X',
#  'KODEC70X']

# %%
df = pd.DataFrame('---', index=arrays, columns=model_products, dtype='str')
# df.loc[('Performance', 'Tryb_Au Gratin'), 'KODDP77H'] = 'TAK'
df
# Out:
#                                                      EOD6C77Z EOD6P77Z  \
# Performance Tryb_Au Gratin                                ---      ---
#             Tryb_grzanie dolne                            ---      ---
#             Tryb_pieczenie chleba                         ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      ---      ---
#             Tryb_rozmrażanie                              ---      ---
# ...                                                       ...      ...
# Other       Linia                                         ---      ---
#             Seria                                         ---      ---
#             Kod partnera                                  ---      ---
#             Cena                                          ---      ---
#             Nazwa                                         ---      ---
#
#                                                      EOD6C77V KOCDH76X  \
# Performance Tryb_Au Gratin                                ---      ---
#             Tryb_grzanie dolne                            ---      ---
#             Tryb_pieczenie chleba                         ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      ---      ---
#             Tryb_rozmrażanie                              ---      ---
# ...                                                       ...      ...
# Other       Linia                                         ---      ---
#             Seria                                         ---      ---
#             Kod partnera                                  ---      ---
#             Cena                                          ---      ---
#             Nazwa                                         ---      ---
#
#                                                      KOBBS39X EOD5C70BX  \
# Performance Tryb_Au Gratin                                ---       ---
#             Tryb_grzanie dolne                            ---       ---
#             Tryb_pieczenie chleba                         ---       ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      ---       ---
#             Tryb_rozmrażanie                              ---       ---
# ...                                                       ...       ...
# Other       Linia                                         ---       ---
#             Seria                                         ---       ---
#             Kod partnera                                  ---       ---
#             Cena                                          ---       ---
#             Nazwa                                         ---       ---
#
#                                                      COB8S39WZ COC8H31Z  \
# Performance Tryb_Au Gratin                                 ---      ---
#             Tryb_grzanie dolne                             ---      ---
#             Tryb_pieczenie chleba                          ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie       ---      ---
#             Tryb_rozmrażanie                               ---      ---
# ...                                                        ...      ...
# Other       Linia                                          ---      ---
#             Seria                                          ---      ---
#             Kod partnera                                   ---      ---
#             Cena                                           ---      ---
#             Nazwa                                          ---      ---
#
#                                                      EOB7S31Z EOC8P39WX  ...  \
# Performance Tryb_Au Gratin                                ---       ---  ...
#             Tryb_grzanie dolne                            ---       ---  ...
#             Tryb_pieczenie chleba                         ---       ---  ...
#             Tryb_konwencjonalne/tradycyjne pieczenie      ---       ---  ...
#             Tryb_rozmrażanie                              ---       ---  ...
# ...                                                       ...       ...  ...
# Other       Linia                                         ---       ---  ...
#             Seria                                         ---       ---  ...
#             Kod partnera                                  ---       ---  ...
#             Cena                                          ---       ---  ...
#             Nazwa                                         ---       ---  ...
#
#                                                      KODEC75Z2 KOBCS31X  \
# Performance Tryb_Au Gratin                                 ---      ---
#             Tryb_grzanie dolne                             ---      ---
#             Tryb_pieczenie chleba                          ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie       ---      ---
#             Tryb_rozmrażanie                               ---      ---
# ...                                                        ...      ...
# Other       Linia                                          ---      ---
#             Seria                                          ---      ---
#             Kod partnera                                   ---      ---
#             Cena                                           ---      ---
#             Nazwa                                          ---      ---
#
#                                                      KODDP77WX EOD3H40BX  \
# Performance Tryb_Au Gratin                                 ---       ---
#             Tryb_grzanie dolne                             ---       ---
#             Tryb_pieczenie chleba                          ---       ---
#             Tryb_konwencjonalne/tradycyjne pieczenie       ---       ---
#             Tryb_rozmrażanie                               ---       ---
# ...                                                        ...       ...
# Other       Linia                                          ---       ---
#             Seria                                          ---       ---
#             Kod partnera                                   ---       ---
#             Cena                                           ---       ---
#             Nazwa                                          ---       ---
#
#                                                      KOAAS31WT EOC6H71X  \
# Performance Tryb_Au Gratin                                 ---      ---
#             Tryb_grzanie dolne                             ---      ---
#             Tryb_pieczenie chleba                          ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie       ---      ---
#             Tryb_rozmrażanie                               ---      ---
# ...                                                        ...      ...
# Other       Linia                                          ---      ---
#             Seria                                          ---      ---
#             Kod partnera                                   ---      ---
#             Cena                                           ---      ---
#             Nazwa                                          ---      ---
#
#                                                      EOD5C71Z EOABS39WZ  \
# Performance Tryb_Au Gratin                                ---       ---
#             Tryb_grzanie dolne                            ---       ---
#             Tryb_pieczenie chleba                         ---       ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      ---       ---
#             Tryb_rozmrażanie                              ---       ---
# ...                                                       ...       ...
# Other       Linia                                         ---       ---
#             Seria                                         ---       ---
#             Kod partnera                                  ---       ---
#             Cena                                          ---       ---
#             Nazwa                                         ---       ---
#
#                                                      EOD3H70X KODEC70X
# Performance Tryb_Au Gratin                                ---      ---
#             Tryb_grzanie dolne                            ---      ---
#             Tryb_pieczenie chleba                         ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      ---      ---
#             Tryb_rozmrażanie                              ---      ---
# ...                                                       ...      ...
# Other       Linia                                         ---      ---
#             Seria                                         ---      ---
#             Kod partnera                                  ---      ---
#             Cena                                          ---      ---
#             Nazwa                                         ---      ---
#
# [94 rows x 93 columns]

# %%
for item in data['products']:
    for spec in item['specifications']:
        if spec['name'] == 'CookingFunctions':
            for s in spec['value'].split('|'):
                val = 'Tryb_' + s
                df.loc[('Performance', val), item['modelId']] = "TAK"
df.head()
# Out:
#                                                      EOD6C77Z EOD6P77Z  \
# Performance Tryb_Au Gratin                                ---      ---
#             Tryb_grzanie dolne                            TAK      TAK
#             Tryb_pieczenie chleba                         ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK      TAK
#             Tryb_rozmrażanie                              ---      ---
#
#                                                      EOD6C77V KOCDH76X  \
# Performance Tryb_Au Gratin                                ---      ---
#             Tryb_grzanie dolne                            TAK      TAK
#             Tryb_pieczenie chleba                         ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK      TAK
#             Tryb_rozmrażanie                              ---      ---
#
#                                                      KOBBS39X EOD5C70BX  \
# Performance Tryb_Au Gratin                                TAK       ---
#             Tryb_grzanie dolne                            TAK       TAK
#             Tryb_pieczenie chleba                         TAK       ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK       TAK
#             Tryb_rozmrażanie                              TAK       ---
#
#                                                      COB8S39WZ COC8H31Z  \
# Performance Tryb_Au Gratin                                 TAK      TAK
#             Tryb_grzanie dolne                             TAK      TAK
#             Tryb_pieczenie chleba                          TAK      TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie       TAK      TAK
#             Tryb_rozmrażanie                               TAK      TAK
#
#                                                      EOB7S31Z EOC8P39WX  ...  \
# Performance Tryb_Au Gratin                                ---       TAK  ...
#             Tryb_grzanie dolne                            TAK       TAK  ...
#             Tryb_pieczenie chleba                         TAK       TAK  ...
#             Tryb_konwencjonalne/tradycyjne pieczenie      ---       TAK  ...
#             Tryb_rozmrażanie                              TAK       TAK  ...
#
#                                                      KODEC75Z2 KOBCS31X  \
# Performance Tryb_Au Gratin                                 ---      ---
#             Tryb_grzanie dolne                             TAK      TAK
#             Tryb_pieczenie chleba                          ---      TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie       TAK      ---
#             Tryb_rozmrażanie                               TAK      TAK
#
#                                                      KODDP77WX EOD3H40BX  \
# Performance Tryb_Au Gratin                                 ---       ---
#             Tryb_grzanie dolne                             TAK       TAK
#             Tryb_pieczenie chleba                          ---       ---
#             Tryb_konwencjonalne/tradycyjne pieczenie       TAK       TAK
#             Tryb_rozmrażanie                               ---       ---
#
#                                                      KOAAS31WT EOC6H71X  \
# Performance Tryb_Au Gratin                                 TAK      ---
#             Tryb_grzanie dolne                             TAK      TAK
#             Tryb_pieczenie chleba                          TAK      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie       TAK      TAK
#             Tryb_rozmrażanie                               TAK      TAK
#
#                                                      EOD5C71Z EOABS39WZ  \
# Performance Tryb_Au Gratin                                ---       TAK
#             Tryb_grzanie dolne                            TAK       TAK
#             Tryb_pieczenie chleba                         ---       TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK       TAK
#             Tryb_rozmrażanie                              TAK       TAK
#
#                                                      EOD3H70X KODEC70X
# Performance Tryb_Au Gratin                                ---      ---
#             Tryb_grzanie dolne                            TAK      TAK
#             Tryb_pieczenie chleba                         ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK      TAK
#             Tryb_rozmrażanie                              TAK      TAK
#
# [5 rows x 93 columns]

# %%
for item in data['products']:
    for spec in item['specifications']:
        if spec['name'] != 'CookingFunctions':
            df.loc[(spec['groupName'], spec['translatedName']), item['modelId']] = spec['value']
df.head()
# Out:
#                                                      EOD6C77Z EOD6P77Z  \
# Performance Tryb_Au Gratin                                ---      ---
#             Tryb_grzanie dolne                            TAK      TAK
#             Tryb_pieczenie chleba                         ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK      TAK
#             Tryb_rozmrażanie                              ---      ---
#
#                                                      EOD6C77V KOCDH76X  \
# Performance Tryb_Au Gratin                                ---      ---
#             Tryb_grzanie dolne                            TAK      TAK
#             Tryb_pieczenie chleba                         ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK      TAK
#             Tryb_rozmrażanie                              ---      ---
#
#                                                      KOBBS39X EOD5C70BX  \
# Performance Tryb_Au Gratin                                TAK       ---
#             Tryb_grzanie dolne                            TAK       TAK
#             Tryb_pieczenie chleba                         TAK       ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK       TAK
#             Tryb_rozmrażanie                              TAK       ---
#
#                                                      COB8S39WZ COC8H31Z  \
# Performance Tryb_Au Gratin                                 TAK      TAK
#             Tryb_grzanie dolne                             TAK      TAK
#             Tryb_pieczenie chleba                          TAK      TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie       TAK      TAK
#             Tryb_rozmrażanie                               TAK      TAK
#
#                                                      EOB7S31Z EOC8P39WX  ...  \
# Performance Tryb_Au Gratin                                ---       TAK  ...
#             Tryb_grzanie dolne                            TAK       TAK  ...
#             Tryb_pieczenie chleba                         TAK       TAK  ...
#             Tryb_konwencjonalne/tradycyjne pieczenie      ---       TAK  ...
#             Tryb_rozmrażanie                              TAK       TAK  ...
#
#                                                      KODEC75Z2 KOBCS31X  \
# Performance Tryb_Au Gratin                                 ---      ---
#             Tryb_grzanie dolne                             TAK      TAK
#             Tryb_pieczenie chleba                          ---      TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie       TAK      ---
#             Tryb_rozmrażanie                               TAK      TAK
#
#                                                      KODDP77WX EOD3H40BX  \
# Performance Tryb_Au Gratin                                 ---       ---
#             Tryb_grzanie dolne                             TAK       TAK
#             Tryb_pieczenie chleba                          ---       ---
#             Tryb_konwencjonalne/tradycyjne pieczenie       TAK       TAK
#             Tryb_rozmrażanie                               ---       ---
#
#                                                      KOAAS31WT EOC6H71X  \
# Performance Tryb_Au Gratin                                 TAK      ---
#             Tryb_grzanie dolne                             TAK      TAK
#             Tryb_pieczenie chleba                          TAK      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie       TAK      TAK
#             Tryb_rozmrażanie                               TAK      TAK
#
#                                                      EOD5C71Z EOABS39WZ  \
# Performance Tryb_Au Gratin                                ---       TAK
#             Tryb_grzanie dolne                            TAK       TAK
#             Tryb_pieczenie chleba                         ---       TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK       TAK
#             Tryb_rozmrażanie                              TAK       TAK
#
#                                                      EOD3H70X KODEC70X
# Performance Tryb_Au Gratin                                ---      ---
#             Tryb_grzanie dolne                            TAK      TAK
#             Tryb_pieczenie chleba                         ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK      TAK
#             Tryb_rozmrażanie                              TAK      TAK
#
# [5 rows x 93 columns]

# %%
for item in data['products']:
    for spec in item['extendedSpecifications']:
        df.loc[(spec['groupName'], spec['translatedName']), item['modelId']] = spec['value']
df.head()
# Out:
#                                                      EOD6C77Z EOD6P77Z  \
# Performance Tryb_Au Gratin                                ---      ---
#             Tryb_grzanie dolne                            TAK      TAK
#             Tryb_pieczenie chleba                         ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK      TAK
#             Tryb_rozmrażanie                              ---      ---
#
#                                                      EOD6C77V KOCDH76X  \
# Performance Tryb_Au Gratin                                ---      ---
#             Tryb_grzanie dolne                            TAK      TAK
#             Tryb_pieczenie chleba                         ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK      TAK
#             Tryb_rozmrażanie                              ---      ---
#
#                                                      KOBBS39X EOD5C70BX  \
# Performance Tryb_Au Gratin                                TAK       ---
#             Tryb_grzanie dolne                            TAK       TAK
#             Tryb_pieczenie chleba                         TAK       ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK       TAK
#             Tryb_rozmrażanie                              TAK       ---
#
#                                                      COB8S39WZ COC8H31Z  \
# Performance Tryb_Au Gratin                                 TAK      TAK
#             Tryb_grzanie dolne                             TAK      TAK
#             Tryb_pieczenie chleba                          TAK      TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie       TAK      TAK
#             Tryb_rozmrażanie                               TAK      TAK
#
#                                                      EOB7S31Z EOC8P39WX  ...  \
# Performance Tryb_Au Gratin                                ---       TAK  ...
#             Tryb_grzanie dolne                            TAK       TAK  ...
#             Tryb_pieczenie chleba                         TAK       TAK  ...
#             Tryb_konwencjonalne/tradycyjne pieczenie      ---       TAK  ...
#             Tryb_rozmrażanie                              TAK       TAK  ...
#
#                                                      KODEC75Z2 KOBCS31X  \
# Performance Tryb_Au Gratin                                 ---      ---
#             Tryb_grzanie dolne                             TAK      TAK
#             Tryb_pieczenie chleba                          ---      TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie       TAK      ---
#             Tryb_rozmrażanie                               TAK      TAK
#
#                                                      KODDP77WX EOD3H40BX  \
# Performance Tryb_Au Gratin                                 ---       ---
#             Tryb_grzanie dolne                             TAK       TAK
#             Tryb_pieczenie chleba                          ---       ---
#             Tryb_konwencjonalne/tradycyjne pieczenie       TAK       TAK
#             Tryb_rozmrażanie                               ---       ---
#
#                                                      KOAAS31WT EOC6H71X  \
# Performance Tryb_Au Gratin                                 TAK      ---
#             Tryb_grzanie dolne                             TAK      TAK
#             Tryb_pieczenie chleba                          TAK      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie       TAK      TAK
#             Tryb_rozmrażanie                               TAK      TAK
#
#                                                      EOD5C71Z EOABS39WZ  \
# Performance Tryb_Au Gratin                                ---       TAK
#             Tryb_grzanie dolne                            TAK       TAK
#             Tryb_pieczenie chleba                         ---       TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK       TAK
#             Tryb_rozmrażanie                              TAK       TAK
#
#                                                      EOD3H70X KODEC70X
# Performance Tryb_Au Gratin                                ---      ---
#             Tryb_grzanie dolne                            TAK      TAK
#             Tryb_pieczenie chleba                         ---      ---
#             Tryb_konwencjonalne/tradycyjne pieczenie      TAK      TAK
#             Tryb_rozmrażanie                              TAK      TAK
#
# [5 rows x 93 columns]

# %%
for item in data['products']:
    if 'price' in item:
        df.loc[('Other', 'Cena'), item['modelId']] = item['price']['formattedValue']
    df.loc[('Other', 'Nazwa'), item['modelId']] = item['name']

# %%
df
# Out:
#                                                                                      EOD6C77Z  \
# Performance Tryb_Au Gratin                                                                ---
#             Tryb_grzanie dolne                                                            TAK
#             Tryb_pieczenie chleba                                                         ---
#             Tryb_konwencjonalne/tradycyjne pieczenie                                      TAK
#             Tryb_rozmrażanie                                                              ---
# ...                                                                                       ...
# Other       Linia                                                                   SteamBake
#             Seria                                                                         600
#             Kod partnera                                                                   ER
#             Cena                                                                     2 149 zł
#             Nazwa                                     Piekarnik parowy SteamBake 600 kataliza
#
#                                                                                      EOD6P77Z  \
# Performance Tryb_Au Gratin                                                                ---
#             Tryb_grzanie dolne                                                            TAK
#             Tryb_pieczenie chleba                                                         ---
#             Tryb_konwencjonalne/tradycyjne pieczenie                                      TAK
#             Tryb_rozmrażanie                                                              ---
# ...                                                                                       ...
# Other       Linia                                                                   SteamBake
#             Seria                                                                         600
#             Kod partnera                                                                   ER
#             Cena                                                                     2 449 zł
#             Nazwa                                     Piekarnik parowy SteamBake 600 pyroliza
#
#                                                                                      EOD6C77V  \
# Performance Tryb_Au Gratin                                                                ---
#             Tryb_grzanie dolne                                                            TAK
#             Tryb_pieczenie chleba                                                         ---
#             Tryb_konwencjonalne/tradycyjne pieczenie                                      TAK
#             Tryb_rozmrażanie                                                              ---
# ...                                                                                       ...
# Other       Linia                                                                   SteamBake
#             Seria                                                                         600
#             Kod partnera                                                                   ER
#             Cena                                                                     2 449 zł
#             Nazwa                                     Piekarnik parowy SteamBake 600 kataliza
#
#                                                                       KOCDH76X  \
# Performance Tryb_Au Gratin                                                 ---
#             Tryb_grzanie dolne                                             TAK
#             Tryb_pieczenie chleba                                          ---
#             Tryb_konwencjonalne/tradycyjne pieczenie                       TAK
#             Tryb_rozmrażanie                                               ---
# ...                                                                        ...
# Other       Linia                                                   SteamCrisp
#             Seria                                                          700
#             Kod partnera                                                    KR
#             Cena                                                      2 949 zł
#             Nazwa                                     Piekarnik SteamCrisp 700
#
#                                                                              KOBBS39X  \
# Performance Tryb_Au Gratin                                                        TAK
#             Tryb_grzanie dolne                                                    TAK
#             Tryb_pieczenie chleba                                                 TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie                              TAK
#             Tryb_rozmrażanie                                                      TAK
# ...                                                                               ...
# Other       Linia                                                          SteamBoost
#             Seria                                                                 800
#             Kod partnera                                                           KR
#             Cena                                                             4 799 zł
#             Nazwa                                     Piekarnik parowy SteamBoost 800
#
#                                                                                     EOD5C70BX  \
# Performance Tryb_Au Gratin                                                                ---
#             Tryb_grzanie dolne                                                            TAK
#             Tryb_pieczenie chleba                                                         ---
#             Tryb_konwencjonalne/tradycyjne pieczenie                                      TAK
#             Tryb_rozmrażanie                                                              ---
# ...                                                                                       ...
# Other       Linia                                                                   SteamBake
#             Seria                                                                         600
#             Kod partnera                                                                   ER
#             Cena                                                                     1 816 zł
#             Nazwa                                     Piekarnik parowy SteamBake 600 kataliza
#
#                                                                             COB8S39WZ  \
# Performance Tryb_Au Gratin                                                        TAK
#             Tryb_grzanie dolne                                                    TAK
#             Tryb_pieczenie chleba                                                 TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie                              TAK
#             Tryb_rozmrażanie                                                      TAK
# ...                                                                               ...
# Other       Linia                                                          SteamBoost
#             Seria                                                                 800
#             Kod partnera                                                           ER
#             Cena                                                                  ---
#             Nazwa                                     Piekarnik parowy SteamBoost 800
#
#                                                                              COC8H31Z  \
# Performance Tryb_Au Gratin                                                        TAK
#             Tryb_grzanie dolne                                                    TAK
#             Tryb_pieczenie chleba                                                 TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie                              TAK
#             Tryb_rozmrażanie                                                      TAK
# ...                                                                               ...
# Other       Linia                                                          SteamCrisp
#             Seria                                                                 700
#             Kod partnera                                                           ER
#             Cena                                                             3 299 zł
#             Nazwa                                     Piekarnik parowy SteamCrisp 700
#
#                                                                              EOB7S31Z  \
# Performance Tryb_Au Gratin                                                        ---
#             Tryb_grzanie dolne                                                    TAK
#             Tryb_pieczenie chleba                                                 TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie                              ---
#             Tryb_rozmrażanie                                                      TAK
# ...                                                                               ...
# Other       Linia                                                          SteamBoost
#             Seria                                                                 800
#             Kod partnera                                                           ER
#             Cena                                                             3 290 zł
#             Nazwa                                     Piekarnik parowy SteamBoost 800
#
#                                                                                      EOC8P39WX  \
# Performance Tryb_Au Gratin                                                                 TAK
#             Tryb_grzanie dolne                                                             TAK
#             Tryb_pieczenie chleba                                                          TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie                                       TAK
#             Tryb_rozmrażanie                                                               TAK
# ...                                                                                        ...
# Other       Linia                                                                   SteamCrisp
#             Seria                                                                          700
#             Kod partnera                                                                    ER
#             Cena                                                                      4 199 zł
#             Nazwa                                     Piekarnik parowy SteamCrisp 700 pyroliza
#
#                                                       ...  \
# Performance Tryb_Au Gratin                            ...
#             Tryb_grzanie dolne                        ...
#             Tryb_pieczenie chleba                     ...
#             Tryb_konwencjonalne/tradycyjne pieczenie  ...
#             Tryb_rozmrażanie                          ...
# ...                                                   ...
# Other       Linia                                     ...
#             Seria                                     ...
#             Kod partnera                              ...
#             Cena                                      ...
#             Nazwa                                     ...
#
#                                                                                     KODEC75Z2  \
# Performance Tryb_Au Gratin                                                                ---
#             Tryb_grzanie dolne                                                            TAK
#             Tryb_pieczenie chleba                                                         ---
#             Tryb_konwencjonalne/tradycyjne pieczenie                                      TAK
#             Tryb_rozmrażanie                                                              TAK
# ...                                                                                       ...
# Other       Linia                                                                   SteamBake
#             Seria                                                                         600
#             Kod partnera                                                                   KR
#             Cena                                                                          ---
#             Nazwa                                     Piekarnik parowy SteamBake 600 kataliza
#
#                                                                              KOBCS31X  \
# Performance Tryb_Au Gratin                                                        ---
#             Tryb_grzanie dolne                                                    TAK
#             Tryb_pieczenie chleba                                                 TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie                              ---
#             Tryb_rozmrażanie                                                      TAK
# ...                                                                               ...
# Other       Linia                                                          SteamBoost
#             Seria                                                                 800
#             Kod partnera                                                           KR
#             Cena                                                             3 999 zł
#             Nazwa                                     Piekarnik parowy SteamBoost 800
#
#                                                                                     KODDP77WX  \
# Performance Tryb_Au Gratin                                                                ---
#             Tryb_grzanie dolne                                                            TAK
#             Tryb_pieczenie chleba                                                         ---
#             Tryb_konwencjonalne/tradycyjne pieczenie                                      TAK
#             Tryb_rozmrażanie                                                              ---
# ...                                                                                       ...
# Other       Linia                                                                   SteamBake
#             Seria                                                                         600
#             Kod partnera                                                                   KR
#             Cena                                                                          ---
#             Nazwa                                     Piekarnik parowy SteamBake 600 pyroliza
#
#                                                                            EOD3H40BX  \
# Performance Tryb_Au Gratin                                                       ---
#             Tryb_grzanie dolne                                                   TAK
#             Tryb_pieczenie chleba                                                ---
#             Tryb_konwencjonalne/tradycyjne pieczenie                             TAK
#             Tryb_rozmrażanie                                                     ---
# ...                                                                              ...
# Other       Linia                                                          SteamBake
#             Seria                                                                600
#             Kod partnera                                                     ER Open
#             Cena                                                            1 349 zł
#             Nazwa                                     Piekarnik parowy SteamBake 600
#
#                                                                           KOAAS31WT  \
# Performance Tryb_Au Gratin                                                      TAK
#             Tryb_grzanie dolne                                                  TAK
#             Tryb_pieczenie chleba                                               TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie                            TAK
#             Tryb_rozmrażanie                                                    TAK
# ...                                                                             ...
# Other       Linia                                                          SteamPro
#             Seria                                                               900
#             Kod partnera                                                         KR
#             Cena                                                           8 399 zł
#             Nazwa                                     Piekarnik parowy SteamPro 900
#
#                                                                              EOC6H71X  \
# Performance Tryb_Au Gratin                                                        ---
#             Tryb_grzanie dolne                                                    TAK
#             Tryb_pieczenie chleba                                                 ---
#             Tryb_konwencjonalne/tradycyjne pieczenie                              TAK
#             Tryb_rozmrażanie                                                      TAK
# ...                                                                               ...
# Other       Linia                                                          SteamCrisp
#             Seria                                                                 700
#             Kod partnera                                                           ER
#             Cena                                                             2 649 zł
#             Nazwa                                     Piekarnik parowy SteamCrisp 700
#
#                                                                                      EOD5C71Z  \
# Performance Tryb_Au Gratin                                                                ---
#             Tryb_grzanie dolne                                                            TAK
#             Tryb_pieczenie chleba                                                         ---
#             Tryb_konwencjonalne/tradycyjne pieczenie                                      TAK
#             Tryb_rozmrażanie                                                              TAK
# ...                                                                                       ...
# Other       Linia                                                                   SteamBake
#             Seria                                                                         600
#             Kod partnera                                                                   ER
#             Cena                                                                     2 199 zł
#             Nazwa                                     Piekarnik parowy SteamBake 600 kataliza
#
#                                                                           EOABS39WZ  \
# Performance Tryb_Au Gratin                                                      TAK
#             Tryb_grzanie dolne                                                  TAK
#             Tryb_pieczenie chleba                                               TAK
#             Tryb_konwencjonalne/tradycyjne pieczenie                            TAK
#             Tryb_rozmrażanie                                                    TAK
# ...                                                                             ...
# Other       Linia                                                          SteamPro
#             Seria                                                               900
#             Kod partnera                                                         ER
#             Cena                                                           6 499 zł
#             Nazwa                                     Piekarnik parowy SteamPro 900
#
#                                                                             EOD3H70X  \
# Performance Tryb_Au Gratin                                                       ---
#             Tryb_grzanie dolne                                                   TAK
#             Tryb_pieczenie chleba                                                ---
#             Tryb_konwencjonalne/tradycyjne pieczenie                             TAK
#             Tryb_rozmrażanie                                                     TAK
# ...                                                                              ...
# Other       Linia                                                          SteamBake
#             Seria                                                                600
#             Kod partnera                                                     ER Open
#             Cena                                                            1 649 zł
#             Nazwa                                     Piekarnik parowy SteamBake 600
#
#                                                                                      KODEC70X
# Performance Tryb_Au Gratin                                                                ---
#             Tryb_grzanie dolne                                                            TAK
#             Tryb_pieczenie chleba                                                         ---
#             Tryb_konwencjonalne/tradycyjne pieczenie                                      TAK
#             Tryb_rozmrażanie                                                              TAK
# ...                                                                                       ...
# Other       Linia                                                                   SteamBake
#             Seria                                                                         600
#             Kod partnera                                                                   KR
#             Cena                                                                     1 949 zł
#             Nazwa                                     Piekarnik parowy SteamBake 600 kataliza
#
# [94 rows x 93 columns]
